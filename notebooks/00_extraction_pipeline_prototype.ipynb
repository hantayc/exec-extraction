# %% [markdown]
# # Extraction Pipeline Prototype
#
# Purpose:
# - Prototype LLM extraction logic
# - Validate schema outputs
# - Test on small sample of documents
#
# Status:
# - Exploratory / non-production

# %%
import os
# Secure 
from dotenv import load_dotenv

from pathlib import Path 
from dataclasses import dataclass
from typing import List, Optional 

# OpenAI 
from openai import OpenAI 
from pydantic import BaseModel

# %%
@dataclass
class Document: 
    doc_id: str
    path: Path
    text: str

# %%
@dataclass
class ExtractionResults: 
    executive_name: str
    role:           str
    effective_date: str 
    evidence_quote: str

# %%
def read_text_file(path: Path) -> str:
    """
    Read in text files

    input: 
    Path object from pathlib module

    output: 

    """
    try: 
        return path.read_text(encoding = "utf-8")
    except UnicodeDecodeError: 
        return path.read_text(encoding="latin-1")

# %%
def normalize_text(text: str) -> str: 
    """
    Normalizing text, line breaks 
    """

        # replace new line characters for Windows, Old Mac, to Unix, Linux, macOS new line characters "\n"
    text = text.replace("\r\n", "\n").replace("\r", "\n")

    # remove whitespaces per line 
    lines = [line.rstrip() for line in text.split("\n")]
    text = "\n".join(lines)

    while "\n\n\n" in text: # replace three line breaks
        text = text.replace("\n\n\n", "\n\n")

    return text.strip()

# %%
def load_documents(input_dir: Path, limit: Optional[int] = None) -> List[Document]:
    """
    Load .txt files from input_dir in sorted order.
    Convert each file into a Document(doc_id, path, text).
    """
    if not input_dir.exists() or not input_dir.is_dir():
        raise FileNotFoundError(f"Input directory not found: {input_dir.resolve()}")

    paths = sorted(input_dir.glob("*.txt"))

    if limit is not None:
        paths = paths[:limit]

    documents: List[Document] = []

    for path in paths:
        raw_text = read_text_file(path)
        clean_text = normalize_text(raw_text)

        documents.append(
            Document(
                doc_id=path.stem,  # filename without ".txt"
                path=path,
                text=clean_text
            )
        )

    return documents

# %%
# Test pipeline 
root_path = '/Users/tahan/Developer/001 Areas/exec-extraction'

data_path = Path(os.path.join(root_path, 'input'))

docs = load_documents(data_path, limit=10)  # pilot

docs
# Out:
# [Document(doc_id='001_acme_cfo_appointment', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/001_acme_cfo_appointment.txt'), text='ACME INDUSTRIAL SOLUTIONS ANNOUNCES APPOINTMENT OF NEW CHIEF FINANCIAL OFFICER\nJanuary 12, 2024 — Chicago, IL\n\nAcme Industrial Solutions, Inc. (“Acme” or the “Company”) today announced that it has appointed Maria L. Chen as Executive Vice President and Chief Financial Officer, effective February 1, 2024. Ms. Chen succeeds Robert J. Meade, who will retire from the Company on January 31, 2024 and will serve as an advisor through the end of the first quarter.\n\n“Maria is a proven financial leader with deep experience in manufacturing and global operations,” said Thomas R. Kellogg, Acme’s President and Chief Executive Officer. “Her expertise in capital allocation and disciplined growth will be instrumental as we execute our multi-year strategy.”\n\nMs. Chen, 46, most recently served as Senior Vice President, Finance at Northline Components, where she led FP&A, treasury, investor relations, and corporate development. Prior to Northline, she held finance leadership roles at Barton Logistics and McKinsey & Company. Ms. Chen holds an M.B.A. from Northwestern University and a B.S. in Accounting from the University of Illinois.\n\nThe Company also announced that Ms. Chen will be appointed a corporate officer of the Company upon her start date.\n\nForward-Looking Statements…'),
#  Document(doc_id='002_riverview_ceo_transition', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/002_riverview_ceo_transition.txt'), text='RIVERVIEW HEALTH SYSTEM NAMES NEW PRESIDENT & CEO\nFor Immediate Release\nApril 3, 2023 — St. Louis, MO\n\nRiverview Health System today announced that its Board of Directors has unanimously selected Dr. Samuel P. Ortega as President and Chief Executive Officer, effective May 15, 2023.\n\nDr. Ortega succeeds Karen Whitfield, who announced her retirement last fall after nine years of service. Whitfield will continue to support Riverview in an advisory capacity through June.\n\n“Sam brings a patient-centered approach and a track record of operational excellence,” said Elaine Morris, Chair of the Riverview Board.\n\nDr. Ortega previously served as Chief Operating Officer of TriCounty Medical Group and earlier held executive roles at MercyCare Hospitals. He is board certified in internal medicine.\n\nAbout Riverview Health System…'),
#  Document(doc_id='003_orbitech_interim_cio', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/003_orbitech_interim_cio.txt'), text='OrbitTech Announces Interim Chief Information Officer\nSeptember 18, 2024\n\nOrbitTech Corp. today announced that Nina Patel has been appointed Interim Chief Information Officer, effective immediately, following the departure of James A. Lang.\n\nMs. Patel has served as OrbitTech’s Vice President of IT Operations since 2021 and has led the Company’s cloud migration program and cybersecurity modernization initiatives.\n\n“Continuity and resilience are our priorities,” said Derek Huang, Chief Executive Officer. “Nina’s deep knowledge of our systems and her steady leadership make her the right person to guide our technology organization during this transition.”\n\nOrbitTech has commenced a search for a permanent CIO, including consideration of internal and external candidates.'),
#  Document(doc_id='004_greenpeak_dual_exec_appointments', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/004_greenpeak_dual_exec_appointments.txt'), text='GreenPeak Energy Announces Chief Legal Officer and Chief People Officer Appointments\nNovember 6, 2023 — Houston, TX\n\nGreenPeak Energy, LLC announced today two executive appointments designed to strengthen its leadership team.\n\nAlyssa M. Hart has been named Senior Vice President, General Counsel and Corporate Secretary, effective December 1, 2023. Hart joins GreenPeak from Seaboard Refining, where she served as Deputy General Counsel.\n\nIn addition, Leonard “Lenny” Brooks has been appointed Senior Vice President and Chief People Officer, effective December 4, 2023. Brooks previously served as Vice President, Talent and Total Rewards at Horizon Utilities.\n\n“Both Alyssa and Lenny bring the expertise we need as we scale,” said Cynthia Delaney, President and CEO of GreenPeak.\n\nGreenPeak also announced that Mark R. Vance, the Company’s current General Counsel, will transition to a special projects role through the end of the year.'),
#  Document(doc_id='005_stonebridge_board_and_exec_role', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/005_stonebridge_board_and_exec_role.txt'), text='Stonebridge Bancorp Appoints New Chief Risk Officer; Adds Director to Board\nMarch 21, 2024 — New York, NY\n\nStonebridge Bancorp, Inc. (NASDAQ: SBBK) today announced that Priya Desai has been appointed Executive Vice President and Chief Risk Officer, effective April 8, 2024. Desai will report to Michael F. Reardon, President and Chief Executive Officer.\n\nDesai succeeds Alan K. Pierce, who will step down as CRO on April 7, 2024. Pierce will remain with Stonebridge as an executive advisor through September.\n\nSeparately, the Company announced that Jordan M. Sato has been elected to the Board of Directors, effective immediately. Sato is the founder and managing partner of Sato Capital and previously served on the boards of several financial services companies.\n\nAbout Stonebridge…'),
#  Document(doc_id='006_harborworks_promotion_cto', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/006_harborworks_promotion_cto.txt'), text='HarborWorks Promotes Engineering Leader to Chief Technology Officer\nMay 2, 2023 — San Francisco, CA\n\nHarborWorks today announced the promotion of Elena R. Gómez to Chief Technology Officer, effective May 1, 2023. Gómez previously served as HarborWorks’ Vice President of Engineering.\n\n“Elena has been central to our platform’s evolution,” said CEO Ravi Narayan. “Her leadership has accelerated our product delivery and strengthened our reliability.”\n\nGómez joined HarborWorks in 2019 after serving as Director of Engineering at BayScale. She holds a B.S. in Computer Science from UC San Diego.'),
#  Document(doc_id='007_westfield_resignation_and_new_cmo', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/007_westfield_resignation_and_new_cmo.txt'), text='Westfield Retail Group Announces Chief Marketing Officer Appointment\nFebruary 27, 2024 — Atlanta, GA\n\nWestfield Retail Group announced today that Tara J. McAllister has been appointed Chief Marketing Officer, effective March 18, 2024.\n\nMcAllister joins Westfield from BrightCart, where she served as SVP, Brand and Growth. She will succeed Daniel Cho, who resigned from the Company to pursue another opportunity. Cho’s resignation is effective March 1, 2024.\n\n“Tara’s digital-first expertise will help us deepen customer engagement,” said Liam O’Connor, President and CEO.'),
#  Document(doc_id='008_novaron_acting_ceo_and_search', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/008_novaron_acting_ceo_and_search.txt'), text='Novaron Biologics Names Acting CEO; Initiates CEO Search\nJune 10, 2024 — Cambridge, MA\n\nNovaron Biologics, Inc. today announced that its Board has appointed Katherine “Kate” Liu as Acting Chief Executive Officer, effective immediately. Liu currently serves as Novaron’s Chief Scientific Officer.\n\nThe appointment follows the unexpected medical leave of CEO Harold E. Finch, who will step away from day-to-day duties while focusing on his health. Finch will remain on the Company’s Board of Directors.\n\nThe Board has initiated a search process to identify a permanent CEO. Novaron stated that it may consider external candidates and internal executives as part of the process.'),
#  Document(doc_id='009_summitco_appointment_with_compensation_details', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/009_summitco_appointment_with_compensation_details.txt'), text='SummitCo Appoints Chief Accounting Officer\n8-K Disclosure Excerpt (Filed August 14, 2023)\n\nOn August 10, 2023, SummitCo, Inc. (the “Company”) appointed Rachel A. Kim as Vice President, Chief Accounting Officer. Ms. Kim will begin employment with the Company on August 28, 2023.\n\nMs. Kim, 39, previously served as Senior Director of Accounting Policy at Pineridge Software. Prior to that, she held positions at Deloitte & Touche LLP.\n\nIn connection with her appointment, Ms. Kim will receive an annual base salary of $285,000 and will be eligible to participate in the Company’s annual incentive plan with a target bonus of 35% of base salary. She will also receive an equity award with a grant-date fair value of $450,000, subject to vesting.'),
#  Document(doc_id='010_tricky_multiple_title_and_effective_date', path=PosixPath('/Users/tahan/Developer/001 Areas/exec-extraction/input/010_tricky_multiple_title_and_effective_date.txt'), text='Press Release\nOctober 30, 2024\n\nLumina Mobility announced today that Anthony J. Rivera will join the company as Chief Operating Officer and President, North America, effective January 6, 2025.\n\nRivera will oversee global operations, manufacturing, and supply chain, and will also lead Lumina’s North America business unit. He will report to CEO Mei Tan.\n\nRivera previously served as Executive Vice President, Global Operations at Vector Automotive. He succeeds Paul N. Jensen, who has served as interim COO since April 2024 and will remain President, International.\n\n“Anthony is the ideal leader to help us scale responsibly,” said Tan.')]

# %% [markdown]
# LLM Testing

# %%
class ExtractionResults(BaseModel): 
    executive_name: str
    role:           str
    effective_date: str 
    evidence_quote: str

current_dir = Path.cwd() 
env_path = Path("..") / ".env"

load_dotenv(env_path)
key = os.getenv("OPENAI_API_KEY")
print(f"Key Loaded: {bool(key)}")

client = OpenAI() 

response = client.responses.parse(
    model="gpt-4.1-mini",
    input=[
        {"role": "system", "content": "Extract the event information and return strictly valid JSON."},
        {
            "role": "user",
            "content": "Acme Corp announced that Jane Doe was appointed Chief Financial Officer effective March 1, 2024.",
        },
    ],
    text_format=ExtractionResults,
)

result = response.output_parsed

print(result)
print(result.model_dump())
# Out:
# Key Loaded: True
